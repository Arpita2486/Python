# %% [markdown]
# # 4.6 Merging and exporting data exercise

# %% [markdown]
# #### Import libraries

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# #### Create path

# %%
path = r'C:\Users\arpit\Documents\CareerFoundry\20250505 Instacart Basket Analysis'

# %% [markdown]
# #### Import dataframes

# %%
# Import dataframe

orders_products_combined = pd.read_pickle(os.path.join(path, '02 data' , 'prepared data' , 'orders_products_combined.pkl'))

df_prods = pd.read_csv(os.path.join(path, '02 data' , 'prepared data' , 'products_cleaned.csv'), index_col = 0)

# %%
# Check the shape of the imported dataframe

orders_products_combined.shape
# Out:
# (32434489, 11)

# %% [markdown]
# #### Understanding the basic information of the dataframes

# %%
# Check dataframe structure

orders_products_combined.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           0   2539329        1             1                   2
# 2           0   2539329        1             1                   2
# 3           0   2539329        1             1                   2
# 4           0   2539329        1             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# ...

# %%
# Check the shape

df_prods.shape
# Out:
# (49672, 5)

# %%
# Check dataframe structure

df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %% [markdown]
# #### Merging dataframe

# %% [markdown]
# **Evaluation**
# There's a key column 'product_id' observed among these two dataframes, indicating a merge is possible, however, as for which type of the merge should be applied to depends on the information we expect to see in the final dataframe. Since the information wouldn't be much useful if it doesn't exist in both dataframes, therefore, the 'inner' merge will be a suitable opion.

# %%
# test merge without overwriting with merge flag 'match'

pd.merge(orders_products_combined , df_prods , on = ['product_id'] , how = 'inner', indicator = 'match' )
# Out:
#           Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0                  0   2539329        1             1                   2
# 1                  0   2539329        1             1                   2
# 2                  0   2539329        1             1                   2
# 3                  0   2539329        1             1                   2
# 4                  0   2539329        1             1                   2
# ...              ...       ...      ...           ...                 ...
# 32404854     3421081   2977660   206209            13                   1
# 32404855     3421081   2977660   206209            13                   1
# 32404856     3421081   2977660   206209            13                   1
# 32404857     3421081   2977660   206209            13                   1
# 32404858     3421081   2977660   206209            13                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %% [markdown]
# **Evaluation**
# As the previous exercise of merged dataframe has created 'merge' column as the flag which would be no use for the new merge of 'orders_products_combined' and 'df_prods', for better presetation, the 'merge' column from the previous merge should be dropped after the new merge has been carried out.

# %%
# actual merge of 'orders_products_combined' and '_df_pords'

df_ords_prods_merge = orders_products_combined.merge(df_prods , on = ['product_id'] , indicator = 'match' )

# %%
# drop the flag column '_merge' from the previous merge

df_ords_prods_merge.drop('_merge', axis = 1 )
# Out:
#           Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0                  0   2539329        1             1                   2
# 1                  0   2539329        1             1                   2
# 2                  0   2539329        1             1                   2
# 3                  0   2539329        1             1                   2
# 4                  0   2539329        1             1                   2
# ...              ...       ...      ...           ...                 ...
# 32404854     3421081   2977660   206209            13                   1
# 32404855     3421081   2977660   206209            13                   1
# 32404856     3421081   2977660   206209            13                   1
# 32404857     3421081   2977660   206209            13                   1
# 32404858     3421081   2977660   206209            13                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %%
# Check output
df_ords_prods_merge.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           0   2539329        1             1                   2
# 2           0   2539329        1             1                   2
# 3           0   2539329        1             1                   2
# 4           0   2539329        1             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge                             product_name  aisle_id  \
# ...

# %%
df_ords_prods_merge.shape
# Out:
# (32404859, 16)

# %% [markdown]
# #### Confirm the results of the merge using the merge flag

# %%
df_ords_prods_merge['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# After merging the resulting dataframe has 32,404,859 rows, and each of those rows have information found in both input data sets, as we used an inner join for the purposes of this project

# %% [markdown]
# #### Export the newly created dataframe

# %%
# Export data to pkl
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge.pkl'))
